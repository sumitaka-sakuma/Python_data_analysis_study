# %%
import pandas as pd

# wikipediaから各表を取得し、テーブル要素数を取得
url = "https://ja.wikipedia.org/wiki/%E3%83%88%E3%83%83%E3%83%97%E3%83%AC%E3%83%99%E3%83%AB%E3%83%89%E3%83%A1%E3%82%A4%E3%83%B3%E4%B8%80%E8%A6%A7#%E5%9B%BD%E5%88%A5%E3%82%B3%E3%83%BC%E3%83%89%E3%83%88%E3%83%83%E3%83%97%E3%83%AC%E3%83%99%E3%83%AB%E3%83%89%E3%83%A1%E3%82%A4%E3%83%B3"
tables = pd.read_html(url)
len(tables)
# Out:
# 43

# %%
# 5番目の表を取得（国別コードトップレベルドメイン表）
df = tables[4]
df
# Out:
#     Name        Entity          Explanation  \
# 0    .ac       アセンション島                  NaN
# 1    .ad          アンドラ                  NaN
# 2    .ae      アラブ首長国連邦                  NaN
# 3    .af       アフガニスタン                  NaN
# 4    .ag  アンティグア・バーブーダ                  NaN
# ..   ...           ...                  ...
# 248  .ye          イエメン                  NaN
# 249  .yt         マヨット島                  NaN
# 250  .za         南アフリカ  Zuid-Afrika (オランダ語)
# 251  .zm          ザンビア                  NaN
# 252  .zw         ジンバブエ                  NaN
#
#                                                  Notes            IDN DNSSEC  \
# 0    広く学術的なサイト（大学など）のために用いられる。アセンション島はイギリス領であるが、イギリ...            Yes    Yes
# 1                        アンドラにおける商標または市民権が必要となる[7][8]。            NaN    Yes
# 2                                                  NaN            NaN     No
# 3                                                  NaN            NaN    Yes
# ...

# %%
# csvファイルに書き出す
df.to_csv("write_data.csv")
