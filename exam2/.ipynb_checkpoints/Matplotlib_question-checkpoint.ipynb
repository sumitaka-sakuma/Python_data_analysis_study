# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 32問
labels = ['spam', 'ham', 'egg']
x = [10, 3, 1]
fig, ax = plt.subplots()
ax.pie(x, labels=labels, startangle=90, counterclock=False, autopct='%1.2f%%')
plt.show()
