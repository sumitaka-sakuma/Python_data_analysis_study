# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(123)

# X軸Y軸ともに0から1までの一様分布から100点をサンプリング
X0 = np.random.uniform(size=(100,2))
# クラス0のラベルを100個生成
y0 = np.repeat(0, 100)

# X軸Y軸ともに-1から0までの一様分布から100点をサンプリング
X1 = np.random.uniform(-1.0, 0.0, size=(100,2))
# クラス1のラベルを100個生成
y1 = np.repeat(1, 100)

# 散布図にプロット
fig, ax = plt.subplots()
ax.scatter(X0[:, 0], X0[:, 1], marker='o', label='class 0')
ax.scatter(X1[:, 0], X1[:, 1], marker='x', label='class 1')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()

plt.show()

# %%
from sklearn.svm import SVC

# %%
# 決定境界、マージン、サポートベクタをプロット
plot_boundry_margin_sv(X0, y0, X1, y1, kernel='linear', C=1e6)

# %%
# マージンの幅を変更
plot_boundry_margin_sv(X0, y0, X1, y1, kernel='linear', C=0.1)

# %%
# 直線で完全に分離できないデータの作成
np.random.seed(123)
X = np.random.random(size=(100, 2))
y = (X[:, 1] > 2*(X[:, 0]-0.5)**2 + 0.5).astype(int)

fig, ax = plt.subplots()
ax.scatter(X[y == 0, 0], X[y == 0, 1], marker='x', label='class 0')
ax.scatter(X[y == 1, 0], X[y == 1, 1], marker='o', label='class 1')
ax.legend()

plt.show()

# %%
# 決定境界、マージン、サポートベクタをプロット
X0, X1 = X[y == 0, :], X[y == 1, :]
y0, y1 = y[y == 0], y[y == 1]
plot_boundry_margin_sv(X0, y0, X1, y1,
                      kernel='rbf', C=1e3, xmin=0, ymin=0)
